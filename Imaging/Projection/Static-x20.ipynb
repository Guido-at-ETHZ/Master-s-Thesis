# %%
# Import required libraries
from google.colab import drive
drive.mount('/content/drive')

import os
import numpy as np
from skimage import io, filters, exposure, morphology, measure, segmentation, img_as_float, img_as_uint
from scipy import ndimage
import glob
import tifffile
from pathlib import Path
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from skimage.feature import peak_local_max

# ======= CONFIGURATION =======
# Set paths specifically for your Google Colab environment
INPUT_DIR = '/content/drive/MyDrive/knowledge/University/Master/Thesis/denoised_ordered/Static-x20'
OUTPUT_DIR = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20'

# Default EDF parameters
DEFAULT_MAX_Z_DIFF = 1      # Maximum allowed z-difference between adjacent pixels
DEFAULT_SIGMA = 1.0         # Sigma for Laplacian operator smoothing
DEFAULT_GAUSS_DENOISE = 0.5 # Sigma for Gaussian denoising

# Define channel names (customize these based on your data)
CHANNEL_NAMES = ['Cadherins', 'Nuclei', 'Golgi']

# ======= UTILITY FUNCTIONS =======

def create_dirs():
    """Create necessary directories for the new output structure"""
    os.makedirs(INPUT_DIR, exist_ok=True)
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # Create the new directory structure for all channels with both background and tophat
    for channel in CHANNEL_NAMES:
        os.makedirs(os.path.join(OUTPUT_DIR, channel, 'tophat'), exist_ok=True)
        os.makedirs(os.path.join(OUTPUT_DIR, channel, 'background'), exist_ok=True)

def normalize_image(img):
    """Normalize image to 0-1 range"""
    img_min = np.min(img)
    img_max = np.max(img)
    if img_max > img_min:
        return (img - img_min) / (img_max - img_min)
    return img

# ======= BACKGROUND REMOVAL =======

def tophat_filter_background(image, radius=15):
    """Remove background using white top-hat filter"""
    # Normalize input to 0-1 range
    img = normalize_image(img_as_float(image))

    # Create structuring element (disk)
    selem = morphology.disk(radius)

    # Apply white top-hat filter (removes background while preserving foreground)
    tophat = morphology.white_tophat(img, selem)

    # Enhance contrast and ensure 0-1 range
    tophat = exposure.rescale_intensity(tophat)

    # Double-check normalization
    tophat = normalize_image(tophat)

    return tophat

# ======= REGIONAL GUIDED EDF METHOD =======

def edf_regional_guided(image_stack, region_size=15, overlap=5, sigma=1.0, gauss_denoise=0.5, max_z_diff=1):
    """
    Regional guided EDF with spatial consistency
    Processes image in overlapping regions to better handle local depth variations
    """
    # Convert to float and ensure 0-1 range
    stack = img_as_float(image_stack)
    stack = normalize_image(stack)
    z_size, height, width = stack.shape

    # Calculate focus measures
    focus_measures = np.zeros((z_size, height, width))

    for z in range(z_size):
        # Apply Gaussian filter to reduce noise
        if gauss_denoise > 0:
            blurred = filters.gaussian(stack[z], sigma=gauss_denoise)
        else:
            blurred = stack[z]

        # Apply Laplacian filter (detects edges/details)
        laplacian = np.abs(filters.laplace(blurred, ksize=3))

        # Apply small Gaussian to make the decision more robust
        if sigma > 0:
            focus_measures[z] = filters.gaussian(laplacian, sigma=sigma)
        else:
            focus_measures[z] = laplacian

    # Create output arrays
    # Changed from int32 to float64 to avoid casting error
    best_z = np.zeros((height, width), dtype=np.float64)
    weights = np.zeros((height, width), dtype=np.float32)

    # Process image in overlapping regions
    for y_start in range(0, height, region_size - overlap):
        for x_start in range(0, width, region_size - overlap):
            # Define region bounds
            y_end = min(y_start + region_size, height)
            x_end = min(x_start + region_size, width)

            # Extract region
            region_focus = focus_measures[:, y_start:y_end, x_start:x_end]

            # Process region with spatial continuity
            region_best_z = edf_with_spatial_continuity_region(
                region_focus,
                max_z_diff=max_z_diff
            )

            # Create weight mask (higher weights in center, lower at edges)
            y_grid, x_grid = np.mgrid[y_start:y_end, x_start:x_end]
            y_center = (y_start + y_end) / 2
            x_center = (x_start + x_end) / 2

            # Calculate distance from center (normalized to 0-1)
            y_dist = np.abs(y_grid - y_center) / (region_size / 2)
            x_dist = np.abs(x_grid - x_center) / (region_size / 2)
            dist = np.maximum(y_dist, x_dist)
            region_weights = np.clip(1.0 - dist, 0.1, 1.0)

            # Convert region_best_z to float64 before multiplying
            region_best_z_float = region_best_z.astype(np.float64)

            # Add weighted contribution to output
            best_z[y_start:y_end, x_start:x_end] += region_best_z_float * region_weights
            weights[y_start:y_end, x_start:x_end] += region_weights

    # Normalize by weights and round to nearest integer
    best_z = np.round(best_z / np.maximum(weights, 1e-6)).astype(np.int32)

    # Ensure best_z values are within valid range
    best_z = np.clip(best_z, 0, z_size - 1)

    # Create output by taking pixels from best z-slices
    result = np.zeros((height, width), dtype=np.float32)
    for z in range(z_size):
        mask = best_z == z
        result[mask] = stack[z][mask]

    # Create a visualization of the focus map (normalized to 0-1)
    focus_map = best_z / (z_size - 1)

    return result, focus_map, best_z

def edf_with_spatial_continuity_region(focus_measures, max_z_diff=1):
    """
    Helper function for regional guided EDF
    Applies spatial continuity to a region's focus measures
    """
    z_size, height, width = focus_measures.shape

    # Find initial z-slice with maximum focus for each pixel
    initial_best_z = np.argmax(focus_measures, axis=0)

    # Create a processed mask to track pixels that have been assigned a final z-value
    processed = np.zeros((height, width), dtype=bool)

    # Create the output z-map that will be filled with spatially consistent z-values
    final_best_z = np.copy(initial_best_z)

    # Function to get valid 4-connected neighbors
    def get_neighbors(y, x):
        neighbors = []
        for ny, nx in [(y-1, x), (y+1, x), (y, x-1), (y, x+1)]:
            if 0 <= ny < height and 0 <= nx < width:
                neighbors.append((ny, nx))
        return neighbors

    # Find seed points - we'll start from pixels with highest confidence
    confidence = np.zeros((height, width))
    for y in range(height):
        for x in range(width):
            z = initial_best_z[y, x]
            confidence[y, x] = focus_measures[z, y, x]

    # Sort pixels by confidence (highest first)
    confidence_threshold = np.percentile(confidence, 95)  # Use top 5% as seeds
    seed_indices = np.where(confidence > confidence_threshold)
    seed_points = list(zip(seed_indices[0], seed_indices[1]))

    # Sort seed points by confidence (highest first)
    seed_points.sort(key=lambda idx: confidence[idx[0], idx[1]], reverse=True)

    # Initialize frontier with seed points
    frontier = seed_points.copy()
    for y, x in frontier:
        processed[y, x] = True

    # Process each point and its neighbors using a breadth-first approach
    while frontier:
        y, x = frontier.pop(0)
        current_z = final_best_z[y, x]

        # Check neighbors
        for ny, nx in get_neighbors(y, x):
            if processed[ny, nx]:
                continue

            # Find best z within allowed range from current pixel
            z_min = max(0, current_z - max_z_diff)
            z_max = min(z_size - 1, current_z + max_z_diff)

            # Extract the relevant slice of focus measures and find best z
            z_slice = focus_measures[z_min:z_max+1, ny, nx]
            relative_best_z = np.argmax(z_slice)
            final_best_z[ny, nx] = z_min + relative_best_z

            processed[ny, nx] = True
            frontier.append((ny, nx))

    # Check if there are any unprocessed pixels left (should be rare)
    unprocessed = ~processed
    if np.any(unprocessed):
        # Assign them the value of nearest processed neighbor
        dist, indices = ndimage.distance_transform_edt(
            unprocessed, return_indices=True)

        # Assign z-values from nearest processed pixel
        for y, x in zip(*np.where(unprocessed)):
            idx_y, idx_x = indices[0, y, x], indices[1, y, x]
            final_best_z[y, x] = final_best_z[idx_y, idx_x]

    return final_best_z

# ======= MAIN PROCESSING FUNCTIONS =======

def process_single_stack(stack, apply_tophat=False, max_z_diff=DEFAULT_MAX_Z_DIFF):
    """
    Process a single z-stack with the regional EDF method
    """
    print(f"Processing stack with shape {stack.shape}...")

    # Convert to float and ensure valid range (0-1)
    stack = img_as_float(stack)

    # Ensure stack values are in 0-1 range
    min_val = np.min(stack)
    max_val = np.max(stack)
    if min_val < 0 or max_val > 1:
        print(f"Normalizing stack from range [{min_val}, {max_val}] to [0, 1]")
        stack = normalize_image(stack)

    # Apply background removal if requested
    if apply_tophat:
        print("Applying tophat background removal...")
        processed_stack = np.zeros_like(stack, dtype=np.float32)
        for z in range(stack.shape[0]):
            processed_stack[z] = tophat_filter_background(stack[z])
        working_stack = processed_stack
    else:
        working_stack = stack

    # Store original slices for comparison
    mid_z_idx = stack.shape[0] // 2

    # Prepare results dictionary
    results = {
        'original_middle': stack[mid_z_idx],
        'original_max': np.max(stack, axis=0)
    }

    # Apply regional method
    print("Applying regional guided EDF...")
    proj, focus_map, _ = edf_regional_guided(
        working_stack, max_z_diff=max_z_diff)
    results['regional_edf'] = proj
    results['focus_map_regional'] = focus_map

    return results

def save_results_to_disk(results, filename, channel_name, apply_tophat):
    """Save results to disk with updated directory structure and naming"""
    base_name = os.path.splitext(filename)[0]

    # Get only the projection result (not focus map)
    key = "regional_edf"
    if key in results:
        # Determine processing type folder
        process_type = "tophat" if apply_tophat else "background"

        # Create appropriate directory path
        output_dir = os.path.join(OUTPUT_DIR, channel_name, process_type)
        os.makedirs(output_dir, exist_ok=True)

        # Create output filename - using just the base name as requested
        output_filename = f"{base_name}_{channel_name}_regional"
        if apply_tophat:
            output_filename += "_tophat"
        output_filename += ".tif"

        output_path = os.path.join(output_dir, output_filename)

        # Normalize to 0-1 range and convert to uint16
        projection = results[key]
        projection_normalized = normalize_image(projection)
        projection_uint = img_as_uint(projection_normalized)

        # Save
        tifffile.imwrite(output_path, projection_uint)
        print(f"Saved {output_path}")

def process_directory(input_dir=INPUT_DIR, max_z_diff=DEFAULT_MAX_Z_DIFF,
                     file_pattern='*.tif*', save_results=True):
    """
    Process all files in a directory with channel-specific settings
    """
    # Get all matching files
    all_files = glob.glob(os.path.join(input_dir, file_pattern), recursive=True)
    all_files.sort()

    if not all_files:
        print(f"No files matching '{file_pattern}' found in {input_dir}")
        return []

    print(f"Found {len(all_files)} files to process")

    # Create output directories
    create_dirs()

    # Process each file
    processed_files = []

    for file_idx, file_path in enumerate(all_files):
        print(f"\nProcessing file {file_idx+1}/{len(all_files)}: {os.path.basename(file_path)}")

        try:
            results = process_file(
                file_path, max_z_diff=max_z_diff,
                save_results=save_results
            )

            if results:
                processed_files.append(file_path)
                print(f"Successfully processed {os.path.basename(file_path)}")

        except Exception as e:
            print(f"Error processing file {os.path.basename(file_path)}: {e}")
            import traceback
            traceback.print_exc()

    print(f"\nSuccessfully processed {len(processed_files)}/{len(all_files)} files")
    return processed_files

def process_file(file_path, max_z_diff=DEFAULT_MAX_Z_DIFF, save_results=True):
    """
    Process a single file with channel-specific processing:
    - Create both tophat and background projections for all channels
    """
    filename = os.path.basename(file_path)
    print(f"Processing file: {filename}")

    # Load image
    try:
        image = tifffile.imread(file_path)
        print(f"Image shape: {image.shape}, dtype: {image.dtype}")
    except Exception as e:
        print(f"Error loading image: {e}")
        return None

    # Handle different dimensionalities
    if len(image.shape) == 3:
        # Single channel z-stack - process with and without tophat
        results_no_tophat = process_single_stack(
            image, apply_tophat=False, max_z_diff=max_z_diff)

        results_tophat = process_single_stack(
            image, apply_tophat=True, max_z_diff=max_z_diff)

        if save_results:
            save_results_to_disk(results_no_tophat, filename, "default", False)
            save_results_to_disk(results_tophat, filename, "default", True)

        return {"default_no_tophat": results_no_tophat, "default_tophat": results_tophat}

    elif len(image.shape) == 4:
        # Multi-channel z-stack with channel-specific processing
        all_results = {}

        # Process each channel with appropriate settings
        for ch_idx in range(image.shape[0]):
            # Extract channel
            channel_data = image[ch_idx]
            ch_name = CHANNEL_NAMES[ch_idx] if ch_idx < len(CHANNEL_NAMES) else f"channel_{ch_idx}"

            # Process each channel with both background and tophat
            print(f"Processing {ch_name} without tophat (background)...")
            results_no_tophat = process_single_stack(
                channel_data, apply_tophat=False, max_z_diff=max_z_diff)

            print(f"Processing {ch_name} with tophat...")
            results_tophat = process_single_stack(
                channel_data, apply_tophat=True, max_z_diff=max_z_diff)

            all_results[f"{ch_name}_no_tophat"] = results_no_tophat
            all_results[f"{ch_name}_tophat"] = results_tophat

            if save_results:
                save_results_to_disk(results_no_tophat, filename, ch_name, False)
                save_results_to_disk(results_tophat, filename, ch_name, True)

        return all_results

    else:
        print(f"Unsupported image dimensions: {len(image.shape)}")
        return None

# Main execution - just call process_directory with your parameters
def main():
    create_dirs()
    processed_files = process_directory(
        input_dir=INPUT_DIR,
        max_z_diff=DEFAULT_MAX_Z_DIFF,
        file_pattern='*.tif*',
        save_results=True
    )
    print(f"Processed {len(processed_files)} files")

if __name__ == "__main__":
    main()
# Out:
# Mounted at /content/drive
# Found 23 files to process
#
# Processing file 1/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03957584500312805, 3.2632763385772705] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03957584500312805, 3.2632763385772705] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009947591461241245, 4.1625189781188965] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009947591461241245, 4.1625189781188965] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0056709591299295425, 4.482115745544434] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0056709591299295425, 4.482115745544434] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq001.tif
#
# Processing file 2/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03917171433568001, 5.5141215324401855] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03917171433568001, 5.5141215324401855] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01304886769503355, 3.4503073692321777] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01304886769503355, 3.4503073692321777] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007152209058403969, 3.744939088821411] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007152209058403969, 3.744939088821411] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq002.tif
#
# Processing file 3/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05667900666594505, 4.3115363121032715] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05667900666594505, 4.3115363121032715] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01826642081141472, 2.988612174987793] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01826642081141472, 2.988612174987793] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008814634755253792, 4.119377613067627] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008814634755253792, 4.119377613067627] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq003.tif
#
# Processing file 4/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05584162846207619, 3.1052234172821045] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05584162846207619, 3.1052234172821045] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.016091879457235336, 4.716756343841553] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.016091879457235336, 4.716756343841553] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01220131479203701, 4.131910800933838] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01220131479203701, 4.131910800933838] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq004.tif
#
# Processing file 5/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.06140467897057533, 2.533118724822998] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.06140467897057533, 2.533118724822998] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01179344579577446, 4.789581298828125] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01179344579577446, 4.789581298828125] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007103949319571257, 4.401707649230957] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007103949319571257, 4.401707649230957] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq005.tif
#
# Processing file 6/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.046166155487298965, 3.1547627449035645] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.046166155487298965, 3.1547627449035645] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010337591171264648, 5.009854793548584] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010337591171264648, 5.009854793548584] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0066842082887887955, 4.663127422332764] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0066842082887887955, 4.663127422332764] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq006.tif
#
# Processing file 7/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0492369644343853, 3.433767557144165] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0492369644343853, 3.433767557144165] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010369286872446537, 5.046295166015625] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010369286872446537, 5.046295166015625] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006584323942661285, 4.79824161529541] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006584323942661285, 4.79824161529541] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq007.tif
#
# Processing file 8/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03541180118918419, 2.716771364212036] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03541180118918419, 2.716771364212036] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011842723935842514, 5.770412921905518] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011842723935842514, 5.770412921905518] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006895720027387142, 4.370982646942139] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006895720027387142, 4.370982646942139] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq008.tif
#
# Processing file 9/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04224635660648346, 8.543597221374512] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04224635660648346, 8.543597221374512] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01364987064152956, 5.296091556549072] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01364987064152956, 5.296091556549072] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006629494950175285, 4.304511070251465] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006629494950175285, 4.304511070251465] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq009.tif
#
# Processing file 10/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0393601693212986, 3.418792486190796] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0393601693212986, 3.418792486190796] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.012031042948365211, 4.735698699951172] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.012031042948365211, 4.735698699951172] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007127709686756134, 4.238102912902832] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007127709686756134, 4.238102912902832] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq010.tif
#
# Processing file 11/23: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011.tif
# Processing file: denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.057352613657712936, 4.429656505584717] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.057352613657712936, 4.429656505584717] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011684023775160313, 4.980165958404541] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011684023775160313, 4.980165958404541] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007123352028429508, 4.261253356933594] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007123352028429508, 4.261253356933594] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_19dec21_20xA_L2RA_FlatA_seq011.tif
#
# Processing file 12/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.044821370393037796, 3.697844982147217] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.044821370393037796, 3.697844982147217] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01571451500058174, 3.424067497253418] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01571451500058174, 3.424067497253418] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008570101112127304, 4.462172508239746] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008570101112127304, 4.462172508239746] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001.tif
#
# Processing file 13/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03976552560925484, 4.06947135925293] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03976552560925484, 4.06947135925293] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01231297291815281, 4.435032367706299] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.01231297291815281, 4.435032367706299] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011050581932067871, 4.554129600524902] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011050581932067871, 4.554129600524902] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002.tif
#
# Processing file 14/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.041552308946847916, 4.1985650062561035] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.041552308946847916, 4.1985650062561035] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009183966554701328, 4.3897385597229] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009183966554701328, 4.3897385597229] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008912326768040657, 4.551841735839844] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008912326768040657, 4.551841735839844] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003.tif
#
# Processing file 15/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.07759001106023788, 3.2303309440612793] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.07759001106023788, 3.2303309440612793] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.013196996413171291, 4.324129104614258] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.013196996413171291, 4.324129104614258] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008095597848296165, 4.5772223472595215] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008095597848296165, 4.5772223472595215] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004.tif
#
# Processing file 16/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03655766323208809, 3.0583391189575195] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03655766323208809, 3.0583391189575195] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.013679571449756622, 2.977820634841919] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.013679571449756622, 2.977820634841919] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006495688110589981, 4.250162124633789] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.006495688110589981, 4.250162124633789] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005.tif
#
# Processing file 17/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03529589623212814, 2.814146041870117] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03529589623212814, 2.814146041870117] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.012708875350654125, 3.5495591163635254] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.012708875350654125, 3.5495591163635254] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0073177930898964405, 4.139338493347168] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.0073177930898964405, 4.139338493347168] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006.tif
#
# Processing file 18/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03860162943601608, 3.1319446563720703] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03860162943601608, 3.1319446563720703] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011300625279545784, 3.8484625816345215] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011300625279545784, 3.8484625816345215] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007796189282089472, 4.920938968658447] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.007796189282089472, 4.920938968658447] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007.tif
#
# Processing file 19/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04369860514998436, 2.9421281814575195] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04369860514998436, 2.9421281814575195] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.014221186749637127, 3.310605764389038] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.014221186749637127, 3.310605764389038] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.00783664733171463, 4.648531913757324] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.00783664733171463, 4.648531913757324] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008.tif
#
# Processing file 20/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05825814604759216, 2.6481821537017822] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.05825814604759216, 2.6481821537017822] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011638445779681206, 3.089193820953369] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.011638445779681206, 3.089193820953369] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.00799970980733633, 4.955873966217041] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.00799970980733633, 4.955873966217041] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009.tif
#
# Processing file 21/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03636298328638077, 4.076766014099121] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.03636298328638077, 4.076766014099121] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009736062958836555, 3.5386149883270264] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009736062958836555, 3.5386149883270264] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008211495354771614, 4.601779460906982] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008211495354771614, 4.601779460906982] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010.tif
#
# Processing file 22/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04027193412184715, 4.175736904144287] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04027193412184715, 4.175736904144287] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010236878879368305, 5.604122638702393] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.010236878879368305, 5.604122638702393] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008147166110575199, 5.138218402862549] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.008147166110575199, 5.138218402862549] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011.tif
#
# Processing file 23/23: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012.tif
# Processing file: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012.tif
# Image shape: (3, 13, 1024, 1024), dtype: float32
# Processing Cadherins without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04574691504240036, 3.367384910583496] to [0, 1]
# Applying regional guided EDF...
# Processing Cadherins with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.04574691504240036, 3.367384910583496] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Cadherins/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat.tif
# Processing Nuclei without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.02196488156914711, 4.824273109436035] to [0, 1]
# Applying regional guided EDF...
# Processing Nuclei with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.02196488156914711, 4.824273109436035] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Nuclei_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Nuclei/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Nuclei_regional_tophat.tif
# Processing Golgi without tophat (background)...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009141278453171253, 4.35088586807251] to [0, 1]
# Applying regional guided EDF...
# Processing Golgi with tophat...
# Processing stack with shape (13, 1024, 1024)...
# Normalizing stack from range [-0.009141278453171253, 4.35088586807251] to [0, 1]
# Applying tophat background removal...
# Applying regional guided EDF...
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/background/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Golgi_regional.tif
# Saved /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-x20/Golgi/tophat/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat.tif
# Successfully processed denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012.tif
#
# Successfully processed 23/23 files
# Processed 23 files
