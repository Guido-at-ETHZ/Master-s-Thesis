# %%
import numpy as np
import tifffile
from scipy import ndimage
from skimage.filters import gaussian
from skimage.filters import threshold_li
from skimage.measure import label
import os
import glob
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define input and output paths
input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/1.4Pa-x20/Cadherins/tophat'
output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane_raw'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all .tif files in the input directory
input_files = glob.glob(os.path.join(input_dir, '*.tif'))
print(f"Found {len(input_files)} .tif files to process")

# Process each file
for input_file in input_files:
    # Get base filename for output
    filename = os.path.basename(input_file)
    base_name = os.path.splitext(filename)[0]

    print(f"Processing: {filename}")

    # Load the image
    img = tifffile.imread(input_file)
    print(f"  Image shape: {img.shape}")

    # Extract Cadherins channel based on image format
    if len(img.shape) == 2:
        # Single channel image (already Cadherins)
        print("  Detected single-channel image, using as is")
        cadherins_channel = img
    elif len(img.shape) == 3 and img.shape[0] == 3:
        # Format is (C, H, W)
        print("  Detected format: (C, H, W)")
        cadherins_channel = img[1]  # Second channel - assuming Cadherins is in channel 1
                                    # Adjust this index if your Cadherins are in a different channel
    elif len(img.shape) == 3 and img.shape[2] == 3:
        # Format is (H, W, C)
        print("  Detected format: (H, W, C)")
        cadherins_channel = img[:, :, 1]  # Second channel - assuming Cadherins is in channel 1
                                          # Adjust this index if your Cadherins are in a different channel
    else:
        print(f"  Unexpected image shape: {img.shape}. Using first channel/plane.")
        if len(img.shape) == 3:
            cadherins_channel = img[0] if img.shape[0] < img.shape[1] else img[:, :, 0]
        else:
            cadherins_channel = img

    # Apply Gaussian blur to reduce noise
    print("  Applying Gaussian blur...")
    cadherins_smoothed = gaussian(cadherins_channel, sigma=1)

    # Apply Li thresholding
    print("  Performing Li thresholding...")
    thresh = threshold_li(cadherins_smoothed)
    binary = cadherins_smoothed > thresh

    # Save the binary mask (main output)
    mask_output = os.path.join(output_dir, f"{base_name}_cadherins_mask.tif")
    tifffile.imwrite(mask_output, binary.astype(np.uint8) * 255)
    print(f"  Saved binary mask to {mask_output}")

    # Print some statistics about the segmentation
    print(f"  Threshold value used: {thresh}")
    print(f"  Processing complete for {filename}\n")

print("All processing complete!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 34 .tif files to process
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.01911318980506774
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03866847845607501
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03345525222306879
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03793449837972607
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.05371238023676827
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.06140456970569014
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.043871244950620156
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.030757126124042983
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.033829509306259886
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03412866132619682
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.01979562514031038
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03815731597189227
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.07189092490104435
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.06829793686669762
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03127590376961796
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.039595644466712626
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.032555127242888705
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.032981524354793304
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.04017261841366636
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.061146980368216045
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.033560094200294016
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03329020097542383
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03751993954351693
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03125751820885998
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03621384041504248
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03370441362293302
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03195756103510426
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.05483088105347867
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.03436324772439266
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.02673412403728144
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.028613450693028397
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.026638184660037822
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.033729446616390345
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Cadherins_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Cadherins_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Saved binary mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Cadherins_regional_tophat_cadherins_mask.tif
#   Threshold value used: 0.029630144995318308
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Cadherins_regional_tophat.tif
#
# All processing complete!

# %%
import numpy as np
import tifffile
import os
import glob
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define input and output paths
cadherins_input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Cadherins_raw'
golgi_input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi'
cadherins_output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane'

# Create output directory if it doesn't exist
os.makedirs(cadherins_output_dir, exist_ok=True)

# Find all Cadherins mask files
cadherins_files = glob.glob(os.path.join(cadherins_input_dir, '*.tif'))
print(f"Found {len(cadherins_files)} Cadherins mask files")

# Get all Golgi mask files
golgi_files = glob.glob(os.path.join(golgi_input_dir, '*.tif'))
print(f"Found {len(golgi_files)} Golgi mask files")

# Process each Cadherins mask
for cadherins_file in cadherins_files:
    # Get filename
    cadherins_filename = os.path.basename(cadherins_file)
    print(f"\nProcessing: {cadherins_filename}")

    # Extract common part from filename for matching
    if '_Cadherins_' in cadherins_filename:
        common_part = cadherins_filename.split('_Cadherins_')[0]
    else:
        # Fallback to just removing extension if pattern doesn't match
        common_part = os.path.splitext(cadherins_filename)[0]

    print(f"  Common identifier: {common_part}")

    # Load the Cadherins mask
    cadherins_mask = tifffile.imread(cadherins_file)
    cadherins_binary = cadherins_mask > 0  # Convert to binary boolean mask

    # Look for matching Golgi file
    matching_golgi_file = None

    for golgi_file in golgi_files:
        golgi_filename = os.path.basename(golgi_file)
        # Check if the common part matches and if it's a Golgi file
        if common_part in golgi_filename and '_Golgi_' in golgi_filename:
            matching_golgi_file = golgi_file
            break

    # Extract the original filename without extension for output naming
    original_name_no_ext = os.path.splitext(cadherins_filename)[0]

    # Process and save cleaned mask if a matching file was found
    if matching_golgi_file:
        # Load the Golgi mask
        golgi_mask = tifffile.imread(matching_golgi_file)
        golgi_binary = golgi_mask > 0  # Convert to binary boolean mask

        # Calculate cleaned mask (Cadherins without Golgi overlap)
        cleaned_cadherins = cadherins_binary & ~golgi_binary

        print(f"  Removed Golgi overlap from Cadherins mask using {os.path.basename(matching_golgi_file)}")

        # Calculate statistics
        original_pixels = np.sum(cadherins_binary)
        cleaned_pixels = np.sum(cleaned_cadherins)
        removed_pixels = original_pixels - cleaned_pixels
        removed_percent = (removed_pixels / original_pixels * 100) if original_pixels > 0 else 0
        print(f"  Removed {removed_pixels} pixels ({removed_percent:.2f}% of original)")

        # Save only the cleaned binary mask
        cleaned_file = os.path.join(cadherins_output_dir, f"{original_name_no_ext}_cleaned.tif")
        tifffile.imwrite(cleaned_file, cleaned_cadherins.astype(np.uint8) * 255)
        print(f"  Saved cleaned mask to {cleaned_file}")

    else:
        print(f"  Warning: No matching Golgi mask found for common identifier: {common_part}")

        # Save the original binary mask if no matching Golgi file was found
        original_file = os.path.join(cadherins_output_dir, f"{original_name_no_ext}_original.tif")
        tifffile.imwrite(original_file, cadherins_binary.astype(np.uint8) * 255)
        print(f"  No cleaning performed. Saved original mask to {original_file}")

print("\nAll processing complete!")
# Out:
# Mounted at /content/drive
# Found 23 Cadherins mask files
# Found 23 Golgi mask files
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat_golgi_labels.tif
#   Removed 80817 pixels (23.54% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat_golgi_labels.tif
#   Removed 74896 pixels (23.37% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat_golgi_labels.tif
#   Removed 74412 pixels (23.38% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat_golgi_labels.tif
#   Removed 81749 pixels (24.57% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat_golgi_labels.tif
#   Removed 64288 pixels (19.47% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat_golgi_labels.tif
#   Removed 58632 pixels (18.77% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat_golgi_labels.tif
#   Removed 53046 pixels (18.08% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat_golgi_labels.tif
#   Removed 64503 pixels (19.63% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat_golgi_labels.tif
#   Removed 78902 pixels (23.67% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat_golgi_labels.tif
#   Removed 78790 pixels (23.65% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat_golgi_labels.tif
#   Removed 90547 pixels (26.89% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat_golgi_labels.tif
#   Removed 94949 pixels (27.52% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat_golgi_labels.tif
#   Removed 91579 pixels (26.24% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat_golgi_labels.tif
#   Removed 89790 pixels (26.76% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat_golgi_labels.tif
#   Removed 87788 pixels (26.87% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat_golgi_labels.tif
#   Removed 89916 pixels (26.09% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat_golgi_labels.tif
#   Removed 78013 pixels (28.72% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat_golgi_labels.tif
#   Removed 84506 pixels (29.45% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat_golgi_labels.tif
#   Removed 89313 pixels (28.41% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat_golgi_labels.tif
#   Removed 96093 pixels (29.75% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat_golgi_labels.tif
#   Removed 30402 pixels (15.22% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Golgi_regional_tophat_golgi_labels.tif
#   Removed 82202 pixels (29.14% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Cadherins_regional_tophat_cadherins_mask.tif
#   Common identifier: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018
#   Removed Golgi overlap from Cadherins mask using denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Golgi_regional_tophat_golgi_labels.tif
#   Removed 84004 pixels (28.53% of original)
#   Saved cleaned mask to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Membrane/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Cadherins_regional_tophat_cadherins_mask_cleaned.tif
#
# All processing complete!
