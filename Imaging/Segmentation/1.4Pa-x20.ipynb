# %% [markdown]
# # Golgi

# %%
import numpy as np
import tifffile
from scipy import ndimage
from skimage.filters import gaussian
from skimage.filters import threshold_li  # Changed from threshold_otsu to threshold_li
from skimage.measure import label
import os
import glob
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define input and output paths
input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/1.4Pa-x20/Golgi/tophat'
output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all .tif files in the input directory
input_files = glob.glob(os.path.join(input_dir, '*.tif'))
print(f"Found {len(input_files)} .tif files to process")

# Process each file
for input_file in input_files:
    # Get base filename for output
    filename = os.path.basename(input_file)
    base_name = os.path.splitext(filename)[0]

    print(f"Processing: {filename}")

    # Load the image
    img = tifffile.imread(input_file)
    print(f"  Image shape: {img.shape}")

    # Extract Golgi channel based on image format
    if len(img.shape) == 2:
        # Single channel image (already Golgi)
        print("  Detected single-channel image, using as is")
        golgi_channel = img
    elif len(img.shape) == 3 and img.shape[0] == 3:
        # Format is (C, H, W)
        print("  Detected format: (C, H, W)")
        golgi_channel = img[2]  # Third channel
    elif len(img.shape) == 3 and img.shape[2] == 3:
        # Format is (H, W, C)
        print("  Detected format: (H, W, C)")
        golgi_channel = img[:, :, 2]  # Third channel
    else:
        print(f"  Unexpected image shape: {img.shape}. Using first channel/plane.")
        if len(img.shape) == 3:
            golgi_channel = img[0] if img.shape[0] < img.shape[1] else img[:, :, 0]
        else:
            golgi_channel = img

    # Apply Gaussian blur to reduce noise
    print("  Applying Gaussian blur...")
    golgi_smoothed = gaussian(golgi_channel, sigma=1)

    # Apply Li thresholding
    print("  Performing Li thresholding...")
    thresh = threshold_li(golgi_smoothed)
    binary = golgi_smoothed > thresh

    # Label connected components
    print("  Labeling connected components...")
    labels = label(binary)  # Directly label the binary image without opening/closing
    print(f"  Segmentation complete. Found {len(np.unique(labels))-1} objects")

    # Save the labeled image (main output)
    labels_output = os.path.join(output_dir, f"{base_name}_golgi_labels.tif")
    tifffile.imwrite(labels_output, labels.astype(np.uint32))
    print(f"  Saved labeled image to {labels_output}")

    # Print some statistics about the segmentation
    print(f"  Threshold value used: {thresh}")
    print(f"  Found {len(np.unique(labels))-1} Golgi objects")
    print(f"  Processing complete for {filename}\n")

print("All processing complete!")
# Out:
# Mounted at /content/drive
# Found 34 .tif files to process
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 447 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.028609630381644904
#   Found 447 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 490 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.02671828398224511
#   Found 490 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 468 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.029328072876915263
#   Found 468 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 426 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.026555216200722653
#   Found 426 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 436 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.023571666092282097
#   Found 436 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 376 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03222020595497648
#   Found 376 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 382 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.028474999119257827
#   Found 382 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 445 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.030876139204659623
#   Found 445 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 449 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.025063596436221275
#   Found 449 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 440 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.02542135425879848
#   Found 440 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 476 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.031027910161485033
#   Found 476 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 492 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.023462540967733588
#   Found 492 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 488 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.031593989764023035
#   Found 488 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 424 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.026919359766990853
#   Found 424 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 437 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.022492555371081743
#   Found 437 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 477 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.031104283415025618
#   Found 477 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_19dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 390 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03099563077857943
#   Found 390 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 369 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.030120120033739976
#   Found 369 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 335 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.033877732054742246
#   Found 335 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 313 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03749805041549984
#   Found 313 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 347 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03705986986837196
#   Found 347 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 391 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.030516051524310094
#   Found 391 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 398 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.0306283835820547
#   Found 398 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 383 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.029124591705082088
#   Found 383 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 400 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03596498425269728
#   Found 400 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 492 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03308127625059532
#   Found 492 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 410 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.03260182647716181
#   Found 410 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 387 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.02795254304349068
#   Found 387 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 387 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.025810070025170422
#   Found 387 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 437 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.02532420777057454
#   Found 437 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 480 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.025500366524557287
#   Found 480 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 509 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.024186568437348226
#   Found 509 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 467 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.030729388436772892
#   Found 467 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_Golgi_regional_tophat.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Golgi_regional_tophat.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Li thresholding...
#   Labeling connected components...
#   Segmentation complete. Found 561 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/1.4Pa-x20/Golgi/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Golgi_regional_tophat_golgi_labels.tif
#   Threshold value used: 0.024736975095453462
#   Found 561 Golgi objects
#   Processing complete for denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_Golgi_regional_tophat.tif
#
# All processing complete!
