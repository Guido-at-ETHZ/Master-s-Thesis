# %%
# !pip install pyclesperanto napari-simpleitk-image-processing
# Out:
# Collecting pyclesperanto
#   Downloading pyclesperanto-0.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (26 kB)
# Collecting napari-simpleitk-image-processing
#   Downloading napari_simpleitk_image_processing-0.4.9-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyclesperanto) (2.0.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from pyclesperanto) (0.12.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pyclesperanto) (3.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from pyclesperanto) (0.10.2)
# Collecting napari-plugin-engine>=0.1.4 (from napari-simpleitk-image-processing)
#   Downloading napari_plugin_engine-0.2.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting simpleitk (from napari-simpleitk-image-processing)
#   Downloading SimpleITK-2.4.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Collecting napari-tools-menu>=0.1.17 (from napari-simpleitk-image-processing)
#   Downloading napari_tools_menu-0.1.20-py3-none-any.whl.metadata (6.8 kB)
# Collecting napari-time-slicer (from napari-simpleitk-image-processing)
#   Downloading napari_time_slicer-0.5.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting napari-skimage-regionprops>=0.5.1 (from napari-simpleitk-image-processing)
#   Downloading napari_skimage_regionprops-0.10.1-py3-none-any.whl.metadata (10 kB)
# Collecting napari-assistant>=0.3.10 (from napari-simpleitk-image-processing)
#   Downloading napari_assistant-0.4.11-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from napari-simpleitk-image-processing) (2.2.2)
# Collecting stackview>=0.3.2 (from napari-simpleitk-image-processing)
#   Downloading stackview-0.14.3-py3-none-any.whl.metadata (15 kB)
# Collecting napari>=0.4.14 (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading napari-0.5.6-py3-none-any.whl.metadata (13 kB)
# Collecting magicgui (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading magicgui-0.10.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/dist-packages (from napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.9.0)
# Collecting loguru (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting jupytext (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupytext-1.16.7-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting napari-workflows>=0.2.10 (from napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading napari_workflows-0.2.11-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from napari-skimage-regionprops>=0.5.1->napari-simpleitk-image-processing) (0.25.2)
# Requirement already satisfied: imageio!=2.22.1 in /usr/local/lib/python3.11/dist-packages (from napari-skimage-regionprops>=0.5.1->napari-simpleitk-image-processing) (2.37.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from napari-skimage-regionprops>=0.5.1->napari-simpleitk-image-processing) (1.2.18)
# Collecting ipycanvas (from stackview>=0.3.2->napari-simpleitk-image-processing)
#   Downloading ipycanvas-0.13.3-py2.py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from stackview>=0.3.2->napari-simpleitk-image-processing) (7.7.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.11/dist-packages (from stackview>=0.3.2->napari-simpleitk-image-processing) (2.0.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from stackview>=0.3.2->napari-simpleitk-image-processing) (6.17.1)
# Collecting ipympl (from stackview>=0.3.2->napari-simpleitk-image-processing)
#   Downloading ipympl-0.9.7-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (from stackview>=0.3.2->napari-simpleitk-image-processing) (1.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pyclesperanto) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->napari-simpleitk-image-processing) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->napari-simpleitk-image-processing) (2025.2)
# Collecting appdirs>=1.4.4 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting app-model<0.4.0,>=0.3.0 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading app_model-0.3.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachey>=0.2.1 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading cachey-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2025.1.31)
# Requirement already satisfied: dask>=2021.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2024.12.1)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.23.0)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.4)
# Collecting napari-console>=0.1.1 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading napari_console-0.1.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting napari-svg>=0.1.8 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading napari_svg-0.2.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting npe2>=0.7.6 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading npe2-0.7.8-py3-none-any.whl.metadata (6.0 kB)
# Collecting numpydoc>=0.9.2 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading numpydoc-1.8.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pint>=0.17 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading Pint-0.24.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (5.9.5)
# Collecting psygnal>=0.5.0 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading psygnal-0.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.11.0)
# Requirement already satisfied: pygments>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.18.0)
# Requirement already satisfied: PyOpenGL>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.1.9)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (6.0.2)
# Collecting qtpy>=2.3.1 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.14.1)
# Collecting superqt>=0.6.7 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading superqt-0.7.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tifffile>=2022.7.28 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2025.3.13)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.13.0)
# Collecting vispy<0.15,>=0.14.1 (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading vispy-0.14.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.17.2)
# Requirement already satisfied: docstring-parser>=0.7 in /usr/local/lib/python3.11/dist-packages (from magicgui->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.16)
# Collecting autopep8 (from napari-workflows>=0.2.10->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading autopep8-2.3.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pyclesperanto) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->napari-skimage-regionprops>=0.5.1->napari-simpleitk-image-processing) (3.4.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (3.0.13)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (6.4.2)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.11/dist-packages (from jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (7.16.6)
# Collecting jupyterlab (from jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyterlab-4.3.6-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.11/dist-packages (from jupytext->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.11/dist-packages (from jupytext->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.4.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from jupytext->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (5.10.4)
# Collecting in-n-out>=0.1.5 (from app-model<0.4.0,>=0.3.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading in_n_out-0.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting pydantic-compat>=0.1.1 (from app-model<0.4.0,>=0.3.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading pydantic_compat-0.1.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting heapdict (from cachey>=0.2.1->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (8.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.2.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.24.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (5.7.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=1.0->jupytext->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.1.2)
# Collecting qtconsole!=4.7.6,!=5.4.2,>=4.5.1 (from napari-console>=0.1.1->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading qtconsole-5.6.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting build>=1 (from npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (13.9.4)
# Collecting tomli-w (from npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.15.2)
# Requirement already satisfied: sphinx>=6 in /usr/local/lib/python3.11/dist-packages (from numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (8.2.3)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.11/dist-packages (from numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.9.0)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pint>=0.17->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.3.7)
# Collecting flexcache>=0.3 (from pint>=0.17->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.17->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.4.0)
# Requirement already satisfied: pooch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image[data]>=0.19.1->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.8.2)
# Collecting pyconify>=0.1.4 (from superqt[iconify]>=0.6.1->magicgui->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading pyconify-0.2.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting freetype-py (from vispy<0.15,>=0.14.1->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting hsluv (from vispy<0.15,>=0.14.1->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading hsluv-5.0.4-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (23.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->jupytext->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.21.1)
# Collecting pycodestyle>=2.12.0 (from autopep8->napari-workflows>=0.2.10->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading pycodestyle-2.13.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.11/dist-packages (from jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.4.0)
# Collecting pyproject_hooks (from build>=1->npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.8.4)
# Collecting jupyter-client>=6.1.12 (from ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.8.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->stackview>=0.3.2->napari-simpleitk-image-processing) (0.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (21.2.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.32.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->stackview>=0.3.2->napari-simpleitk-image-processing) (0.2.13)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.0.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.2.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.6)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->npe2>=0.7.6->napari>=0.4.14->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.5.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.3.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (2.22)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing) (24.11.1)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->napari-assistant>=0.3.10->napari-simpleitk-image-processing)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading pyclesperanto-0.16.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (881 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 13.1 MB/s eta 0:00:00
# Downloading napari_simpleitk_image_processing-0.4.9-py3-none-any.whl (19 kB)
# Downloading napari_assistant-0.4.11-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 20.3 MB/s eta 0:00:00
# Downloading napari_plugin_engine-0.2.0-py3-none-any.whl (33 kB)
# Downloading napari_skimage_regionprops-0.10.1-py3-none-any.whl (33 kB)
# Downloading napari_time_slicer-0.5.0-py3-none-any.whl (10 kB)
# Downloading napari_tools_menu-0.1.20-py3-none-any.whl (7.6 kB)
# Downloading stackview-0.14.3-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.6 MB/s eta 0:00:00
# Downloading SimpleITK-2.4.1-cp311-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 18.3 MB/s eta 0:00:00
# Downloading napari-0.5.6-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.2 MB/s eta 0:00:00
# Downloading magicgui-0.10.0-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 8.1 MB/s eta 0:00:00
# Downloading napari_workflows-0.2.11-py3-none-any.whl (15 kB)
# Downloading ipycanvas-0.13.3-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 7.8 MB/s eta 0:00:00
# Downloading ipympl-0.9.7-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.7/515.7 kB 24.5 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupytext-1.16.7-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.2/154.2 kB 8.1 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.0 MB/s eta 0:00:00
# Downloading app_model-0.3.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 4.5 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading cachey-0.2.1-py3-none-any.whl (6.4 kB)
# Downloading napari_console-0.1.3-py3-none-any.whl (10.0 kB)
# Downloading napari_svg-0.2.1-py3-none-any.whl (16 kB)
# Downloading npe2-0.7.8-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 6.8 MB/s eta 0:00:00
# Downloading numpydoc-1.8.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 4.5 MB/s eta 0:00:00
# Downloading Pint-0.24.4-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 21.7 MB/s eta 0:00:00
# Downloading psygnal-0.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (765 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 31.6 MB/s eta 0:00:00
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 8.1 MB/s eta 0:00:00
# Downloading superqt-0.7.3-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 7.4 MB/s eta 0:00:00
# Downloading vispy-0.14.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 52.5 MB/s eta 0:00:00
# Downloading autopep8-2.3.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.8 MB/s eta 0:00:00
# Downloading jupyterlab-4.3.6-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 67.1 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading in_n_out-0.2.1-py3-none-any.whl (19 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.8 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.1 MB/s eta 0:00:00
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 21.6 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 8.8 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.0 MB/s eta 0:00:00
# Downloading pycodestyle-2.13.0-py2.py3-none-any.whl (31 kB)
# Downloading pyconify-0.2.1-py3-none-any.whl (19 kB)
# Downloading pydantic_compat-0.1.2-py3-none-any.whl (13 kB)
# Downloading qtconsole-5.6.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 5.4 MB/s eta 0:00:00
# Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.4 MB/s eta 0:00:00
# Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Downloading hsluv-5.0.4-py2.py3-none-any.whl (5.3 kB)
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.7 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: simpleitk, heapdict, appdirs, uri-template, types-python-dateutil, tomli-w, rfc3986-validator, rfc3339-validator, qtpy, python-json-logger, pyproject_hooks, pycodestyle, psygnal, overrides, napari-plugin-engine, loguru, json5, jedi, in-n-out, hsluv, freetype-py, fqdn, flexparser, flexcache, cachey, async-lru, vispy, superqt, pyconify, pint, jupyter-server-terminals, jupyter-client, build, autopep8, arrow, pydantic-compat, pyclesperanto, numpydoc, napari-svg, isoduration, qtconsole, npe2, magicgui, app-model, napari-console, jupytext, jupyter-events, napari, napari-tools-menu, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, ipympl, ipycanvas, stackview, napari-workflows, napari-time-slicer, napari-skimage-regionprops, napari-assistant, napari-simpleitk-image-processing
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.16.0
#     Uninstalling jupyter-server-1.16.0:
#       Successfully uninstalled jupyter-server-1.16.0
# Successfully installed app-model-0.3.1 appdirs-1.4.4 arrow-1.3.0 async-lru-2.0.5 autopep8-2.3.2 build-1.2.2.post1 cachey-0.2.1 flexcache-0.3 flexparser-0.4 fqdn-1.5.1 freetype-py-2.5.1 heapdict-1.0.1 hsluv-5.0.4 in-n-out-0.2.1 ipycanvas-0.13.3 ipympl-0.9.7 isoduration-20.11.0 jedi-0.19.2 json5-0.10.0 jupyter-1.1.1 jupyter-client-7.4.9 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.6 jupyterlab-server-2.27.3 jupytext-1.16.7 loguru-0.7.3 magicgui-0.10.0 napari-0.5.6 napari-assistant-0.4.11 napari-console-0.1.3 napari-plugin-engine-0.2.0 napari-simpleitk-image-processing-0.4.9 napari-skimage-regionprops-0.10.1 napari-svg-0.2.1 napari-time-slicer-0.5.0 napari-tools-menu-0.1.20 napari-workflows-0.2.11 npe2-0.7.8 numpydoc-1.8.0 overrides-7.7.0 pint-0.24.4 psygnal-0.12.0 pyclesperanto-0.16.1 pycodestyle-2.13.0 pyconify-0.2.1 pydantic-compat-0.1.2 pyproject_hooks-1.2.0 python-json-logger-3.3.0 qtconsole-5.6.1 qtpy-2.4.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 simpleitk-2.4.1 stackview-0.14.3 superqt-0.7.3 tomli-w-1.2.0 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 vispy-0.14.3

# %%
import numpy as np
import os
import glob
import tifffile
from skimage.exposure import rescale_intensity
from google.colab import drive
import pyclesperanto as cle  # using pyclesperanto instead of pyclesperanto_prototype
import napari_simpleitk_image_processing as nsitk

# Mount Google Drive
drive.mount('/content/drive')

# Define input and output paths
input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/denoised/trial'
output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/WNLA/'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all files in the input directory
input_files = glob.glob(os.path.join(input_dir, "*.tif"))
input_files.extend(glob.glob(os.path.join(input_dir, "*.tiff")))

print(f"Found {len(input_files)} .tif/.tiff files in {input_dir}")
if len(input_files) == 0:
    print("No .tif/.tiff files found. Please check the input directory.")
    # Option to look for other file types
    all_files = glob.glob(os.path.join(input_dir, "*"))
    if len(all_files) > 0:
        print(f"Found {len(all_files)} files of other types in the directory.")
        print("Available files:")
        for file in all_files:
            print(f" - {os.path.basename(file)}")

# Process each file
for input_path in input_files:
    filename = os.path.basename(input_path)
    base_filename = os.path.splitext(filename)[0]

    # Define output filename using the requested naming convention
    output_filename = f"{base_filename}_hole_projection.tif"
    output_path = os.path.join(output_dir, output_filename)

    print(f"\nProcessing: {filename}")
    print(f"Output will be saved as: {output_filename}")

    # Load the image
    try:
        img = tifffile.imread(input_path)
        print(f"Image loaded successfully, shape: {img.shape}")
    except Exception as e:
        print(f"Error loading image {filename}: {e}")
        print("Skipping to next file")
        continue

    # Handle 4D images (C, Z, Y, X)
    if len(img.shape) == 4:
        print(f"Detected 4D image with shape {img.shape}")
        print("Expected format: (Channels, Z-slices, Height, Width)")

        # Extract first channel for processing
        print("Extracting first channel (index 0)...")
        img_channel = img[0]  # Shape: (Z, Y, X)
        print(f"Channel extracted, shape: {img_channel.shape}")

        # Step 1: Adaptive histogram equalization using napari_simpleitk_image_processing
        print("1. Applying adaptive histogram equalization...")
        try:
            # Using nsitk for adaptive histogram equalization (same parameters as in your example)
            img_equalized = nsitk.adaptive_histogram_equalization(img_channel, 1.0, 1.0, 0, 0, 0)
            print("  napari_simpleitk adaptive histogram equalization succeeded")
        except Exception as e:
            print(f"  napari_simpleitk failed: {e}")
            # Fallback to SimpleITK if available, or skip this step
            print("  Skipping adaptive histogram equalization due to error")
            img_equalized = img_channel  # Use original if adaptive histogram fails

        # Step 2: Gamma correction using pyclesperanto
        print("2. Applying gamma correction...")
        try:
            # Using pyclesperanto for gamma correction (same parameters as in your example)
            img_gamma = cle.gamma_correction(img_equalized, None, 1.0)
            print("  pyclesperanto gamma correction succeeded")
        except Exception as e:
            print(f"  pyclesperanto gamma correction failed: {e}")
            # Fallback to a simple power law transformation
            img_gamma = img_equalized
            print("  Skipping gamma correction due to error")

        # Step 3: Sum z-projection using pyclesperanto
        print("3. Applying sum z-projection...")
        try:
            # Using pyclesperanto for z-projection (same as in your example)
            img_projected = cle.sum_z_projection(img_gamma)
            print("  pyclesperanto sum_z_projection succeeded")
        except Exception as e:
            print(f"  pyclesperanto z-projection failed: {e}")
            # Fallback to numpy
            img_projected = np.sum(img_gamma, axis=0)
            print("  Used numpy fallback for z-projection")

        # Step 4: Final enhancements on the projected image
        print("4. Applying final enhancements...")
        # Normalize to 0-1 range for better visibility
        img_final = rescale_intensity(img_projected, out_range=(0, 1))

        # Save the final result
        tifffile.imwrite(output_path, img_final.astype(np.float32))
        print(f"  Saved final result as {output_filename}")

    else:
        # Handle 2D or 3D images
        # If 3D image, check if it's (Z, Y, X) or (Y, X, C)
        if len(img.shape) == 3:
            if img.shape[2] <= 4:  # Likely (Y, X, C) format with RGB/RGBA
                print(f"Detected color image with shape {img.shape}")
                # Take first channel
                img_channel = img[:, :, 0]
                print(f"Extracted first color channel, shape: {img_channel.shape}")
            else:  # Likely (Z, Y, X) format
                print(f"Detected 3D image with shape {img.shape}")
                # Keep as is for 3D processing
                img_channel = img
        else:
            # 2D image
            print(f"Detected 2D image with shape {img.shape}")
            img_channel = img

        # Processing steps depend on dimensionality
        if len(img_channel.shape) == 3:  # 3D image (Z, Y, X)
            # Apply the napari and pyclesperanto functions
            print("1. Applying adaptive histogram equalization...")
            try:
                # Using nsitk for adaptive histogram equalization
                img_equalized = nsitk.adaptive_histogram_equalization(img_channel, 1.0, 1.0, 0, 0, 0)
                print("  napari_simpleitk adaptive histogram equalization succeeded")
            except Exception as e:
                print(f"  napari_simpleitk failed: {e}")
                # Fallback to original image
                img_equalized = img_channel
                print("  Skipping adaptive histogram equalization due to error")

            # Gamma correction
            print("2. Applying gamma correction...")
            try:
                # Using pyclesperanto
                img_gamma = cle.gamma_correction(img_equalized, None, 1.0)
                print("  pyclesperanto gamma correction succeeded")
            except Exception as e:
                print(f"  pyclesperanto approach failed: {e}")
                # Fallback to original
                img_gamma = img_equalized
                print("  Skipping gamma correction due to error")

            # Z-projection
            print("3. Applying sum z-projection...")
            try:
                # Using pyclesperanto
                img_projected = cle.sum_z_projection(img_gamma)
                print("  pyclesperanto sum_z_projection succeeded")
            except Exception as e:
                print(f"  pyclesperanto z-projection failed: {e}")
                # Fallback to numpy
                img_projected = np.sum(img_gamma, axis=0)
                print("  Used numpy fallback for z-projection")

            # Final enhancements
            print("4. Applying final enhancements...")
            img_final = rescale_intensity(img_projected, out_range=(0, 1))

            # Save the final result
            tifffile.imwrite(output_path, img_final.astype(np.float32))
            print(f"  Saved final result as {output_filename}")

        else:  # 2D image
            # Apply operations directly
            print("1. Applying adaptive histogram equalization...")
            try:
                # Using nsitk for adaptive histogram equalization
                img_equalized = nsitk.adaptive_histogram_equalization(img_channel, 1.0, 1.0, 0, 0, 0)
                print("  napari_simpleitk adaptive histogram equalization succeeded")
            except Exception as e:
                print(f"  napari_simpleitk failed: {e}")
                # Fallback to original image
                img_equalized = img_channel
                print("  Skipping adaptive histogram equalization due to error")

            # Gamma correction
            print("2. Applying gamma correction...")
            try:
                # Using pyclesperanto
                img_gamma = cle.gamma_correction(img_equalized, None, 1.0)
                print("  pyclesperanto gamma correction succeeded")
            except Exception as e:
                print(f"  pyclesperanto approach failed: {e}")
                # Fallback to original
                img_gamma = img_equalized
                print("  Skipping gamma correction due to error")

            # This is the final result for 2D images
            print("3. Applying final enhancements...")
            img_final = rescale_intensity(img_gamma, out_range=(0, 1))

            # Save the final result
            tifffile.imwrite(output_path, img_final.astype(np.float32))
            print(f"  Saved final result as {output_filename}")

    print(f"Completed processing: {filename}")

print("\nAll processing completed!")
# Out:
# /usr/local/lib/python3.11/dist-packages/pyclesperanto/_core.py:105: RuntimeWarning: No backend available. Please install either OpenCL or CUDA on your system.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pyclesperanto/_core.py:172: RuntimeWarning: Error while initialising pyclesperanto: No backend available.
#
# No GPU Backend found.
#
# pyclesperanto requires either CUDA or OpenCL libraries to be installed on your system to work.
# Please ensure you have the appropriate drivers installed and up-to-date.
#
# Alternatively, you may need to install the following additional package:
# - MacOS: `conda install -c conda-forge ocl_icd_wrapper_apple`
# - Linux: `conda install -c conda-forge ocl-icd-system`
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/napari_tools_menu/__init__.py:10: UserWarning: Importing QT failed; now introducing dummy definitions of QMenu class and register_function decorator.
#   warnings.warn("Importing QT failed; now introducing dummy definitions of QMenu class and register_function decorator.")
# /usr/local/lib/python3.11/dist-packages/napari_skimage_regionprops/_table.py:7: UserWarning: No Qt bindings could be found
#   warnings.warn(str(e))
# Mounted at /content/drive
# Found 1 .tif/.tiff files in /content/drive/MyDrive/knowledge/University/Master/Thesis/denoised/trial
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018 (2).tif
# Output will be saved as: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018 (2)_hole_projection.tif
# Image loaded successfully, shape: (3, 13, 1024, 1024)
# Detected 4D image with shape (3, 13, 1024, 1024)
# Expected format: (Channels, Z-slices, Height, Width)
# Extracting first channel (index 0)...
# Channel extracted, shape: (13, 1024, 1024)
# 1. Applying adaptive histogram equalization...
#   napari_simpleitk adaptive histogram equalization succeeded
# 2. Applying gamma correction...
#   pyclesperanto gamma correction failed: Backend not selected.
#   Skipping gamma correction due to error
# 3. Applying sum z-projection...
#   pyclesperanto z-projection failed: Backend not selected.
#   Used numpy fallback for z-projection
# 4. Applying final enhancements...
#   Saved final result as denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018 (2)_hole_projection.tif
# Completed processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018 (2).tif
#
# All processing completed!

# %%
import numpy as np
import os
import glob
import tifffile
from scipy import ndimage
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the input and output paths
input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/NLA/'
output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all processed files in the input directory
processed_files = glob.glob(os.path.join(input_dir, "*_hole_projection.tif"))

print(f"Found {len(processed_files)} processed files in {input_dir}")
if len(processed_files) == 0:
    print("No processed files found. Please check the input directory.")
    # Option to look for other file types
    all_files = glob.glob(os.path.join(input_dir, "*"))
    if len(all_files) > 0:
        print(f"Found {len(all_files)} files of other types in the directory.")
        print("Available files:")
        for file in all_files:
            print(f" - {os.path.basename(file)}")

# Process each file
for file_path in processed_files:
    filename = os.path.basename(file_path)
    print(f"\nProcessing: {filename}")

    # Load the image
    try:
        img = tifffile.imread(file_path)
        print(f"Image loaded successfully, shape: {img.shape}")
    except Exception as e:
        print(f"Error loading image {filename}: {e}")
        print("Skipping to next file")
        continue

    # Normalize image to [0, 1] range for processing
    img_min = np.min(img)
    img_max = np.max(img)
    if img_max > img_min:  # Check to prevent division by zero
        img_norm = (img - img_min) / (img_max - img_min)
    else:
        img_norm = img.astype(float)
        print("  Warning: Image has constant values, normalization skipped")

    # Estimate background using a large Gaussian filter
    print("Applying illumination correction via division method...")
    sigma = max(img_norm.shape) // 20  # Divisor of 20 for division method
    print(f"  Using Gaussian filter with sigma = {sigma}")

    # Apply Gaussian filter to estimate background
    background = ndimage.gaussian_filter(img_norm, sigma=sigma)

    # Use DIVISION instead of subtraction to correct illumination
    illumination_corrected = img_norm / (background + 1e-6)  # Adding small value to prevent division by zero

    # Normalize the result to [0, 1] range
    illumination_min = np.min(illumination_corrected)
    illumination_max = np.max(illumination_corrected)
    if illumination_max > illumination_min:  # Check to prevent division by zero
        illumination_corrected = (illumination_corrected - illumination_min) / (illumination_max - illumination_min)

    # Save the illumination corrected image to the output directory
    output_path = os.path.join(output_dir, filename)
    tifffile.imwrite(output_path, illumination_corrected.astype(np.float32))
    print(f"  Saved illumination corrected image to: {output_path}")

print("\nAll illumination correction completed!")
# Out:
# Mounted at /content/drive
# Found 18 processed files in /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/NLA/
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq016_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq018_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq015_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq013_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq014_hole_projection.tif
#
# Processing: denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_hole_projection.tif
# Image loaded successfully, shape: (1024, 1024)
# Applying illumination correction via division method...
#   Using Gaussian filter with sigma = 51
#   Saved illumination corrected image to: /content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/holes_1.4Pa-A-2/LA/denoised_1.4Pa_A1_20dec21_20xA_L2RA_FlatA_seq017_hole_projection.tif
#
# All illumination correction completed!
