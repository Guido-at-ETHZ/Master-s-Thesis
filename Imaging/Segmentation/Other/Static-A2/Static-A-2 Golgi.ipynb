# %%
import numpy as np
import tifffile
from scipy import ndimage
from skimage.filters import gaussian, threshold_otsu
from skimage.measure import label
import os
import glob
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define input and output paths
input_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Projected/Static-A-2/Golgi'
output_dir = '/content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi'

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Find all .tif files in the input directory
input_files = glob.glob(os.path.join(input_dir, '*.tif'))
print(f"Found {len(input_files)} .tif files to process")

# Process each file
for input_file in input_files:
    # Get base filename for output
    filename = os.path.basename(input_file)
    base_name = os.path.splitext(filename)[0]

    print(f"Processing: {filename}")

    # Load the image
    img = tifffile.imread(input_file)
    print(f"  Image shape: {img.shape}")

    # Extract Golgi channel based on image format
    if len(img.shape) == 2:
        # Single channel image (already Golgi)
        print("  Detected single-channel image, using as is")
        golgi_channel = img
    elif len(img.shape) == 3 and img.shape[0] == 3:
        # Format is (C, H, W)
        print("  Detected format: (C, H, W)")
        golgi_channel = img[2]  # Third channel
    elif len(img.shape) == 3 and img.shape[2] == 3:
        # Format is (H, W, C)
        print("  Detected format: (H, W, C)")
        golgi_channel = img[:, :, 2]  # Third channel
    else:
        print(f"  Unexpected image shape: {img.shape}. Using first channel/plane.")
        if len(img.shape) == 3:
            golgi_channel = img[0] if img.shape[0] < img.shape[1] else img[:, :, 0]
        else:
            golgi_channel = img

    # Apply Gaussian blur to reduce noise
    print("  Applying Gaussian blur...")
    golgi_smoothed = gaussian(golgi_channel, sigma=1)

    # Apply Otsu thresholding
    print("  Performing Otsu thresholding...")
    thresh = threshold_otsu(golgi_smoothed)
    binary = golgi_smoothed > thresh

    # Apply erosion to remove small noise
    print("  Applying erosion...")
    eroded = ndimage.binary_erosion(binary, iterations=3)

    # Apply opening (erosion followed by dilation) to smooth boundaries
    print("  Applying opening...")
    opened = ndimage.binary_opening(eroded, iterations=1)

    # Label connected components
    print("  Labeling connected components...")
    labels = label(opened)
    print(f"  Segmentation complete. Found {len(np.unique(labels))-1} objects")

    # Save the different outputs

    # Save the labeled image (main output) - this is the only output we'll keep
    labels_output = os.path.join(output_dir, f"{base_name}_golgi_labels.tif")
    tifffile.imwrite(labels_output, labels.astype(np.uint32))
    print(f"  Saved labeled image to {labels_output}")

    # Print some statistics about the segmentation
    print(f"  Threshold value used: {thresh}")
    print(f"  Found {len(np.unique(labels))-1} Golgi objects")
    print(f"  Processing complete for {filename}\n")

print("All processing complete!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 18 .tif files to process
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 194 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.24877392454964797
#   Found 194 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq001_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 281 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.24214572297628079
#   Found 281 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq002_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 285 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.24136295219320125
#   Found 285 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq003_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 156 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.3109288742615368
#   Found 156 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq004_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 144 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.30558655624130626
#   Found 144 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq005_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 181 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.34318230920887327
#   Found 181 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq006_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 185 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.27162245020518383
#   Found 185 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq007_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 233 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.29159838088888135
#   Found 233 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq008_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 282 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.23271635918333894
#   Found 282 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq009_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 175 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.22542919783408877
#   Found 175 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq010_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 219 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.21728677851076106
#   Found 219 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq011_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 249 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.2253370418931993
#   Found 249 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_20xA_L2RA_FlatA_seq012_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq002_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 77 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq002_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.34967477467093033
#   Found 77 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq002_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq003_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 82 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq003_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.32901746964923223
#   Found 82 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq003_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq004_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 68 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq004_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.34883703233674734
#   Found 68 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq004_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq005_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 65 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq005_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.3652616447217033
#   Found 65 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq005_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq006_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 70 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq006_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.3300991822405205
#   Found 70 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq006_contrast_Golgi.tif
#
# Processing: denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq007_contrast_Golgi.tif
#   Image shape: (1024, 1024)
#   Detected single-channel image, using as is
#   Applying Gaussian blur...
#   Performing Otsu thresholding...
#   Applying erosion...
#   Applying opening...
#   Labeling connected components...
#   Segmentation complete. Found 82 objects
#   Saved labeled image to /content/drive/MyDrive/knowledge/University/Master/Thesis/Segmented/Static-A-2/Golgi/denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq007_contrast_Golgi_golgi_labels.tif
#   Threshold value used: 0.3378703219358951
#   Found 82 Golgi objects
#   Processing complete for denoised_0Pa_A1_20dec21_40x_L2RA_FlatA_seq007_contrast_Golgi.tif
#
# All processing complete!
